# %% [markdown]
# <a href="https://colab.research.google.com/github/nirmalsinghania2008/Project_Phase2/blob/master/Resnet_EIP3_Phase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 200
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

depth = 18
# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
#     if (depth - 2) % 6 != 0:
#         raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks, steps_per_epoch = epochs )
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks, steps_per_epoch = epochs)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 16)   64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 16)   2320        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 16)   64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 16)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 16)   2320        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 16)   64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 32, 32, 16)   0           activation_20[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 16)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 16)   2320        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 16)   64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 16)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 16)   2320        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 16)   64          conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 16)   0           activation_22[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 16)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 32)   4640        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 32)   544         activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 32)   0           conv2d_29[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 32)   0           activation_26[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 32)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     18496       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 64)     256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 8, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 64)     36928       activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 64)     2112        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 64)     256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 64)     0           conv2d_34[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 8, 8, 64)     0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 64)     36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 64)     256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 64)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 64)     36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 64)     256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 64)     0           activation_30[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 64)     0           add_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 64)     0           activation_32[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 64)           0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           650         flatten_2[0][0]
# ==================================================================================================
# Total params: 176,554
# Trainable params: 175,626
# Non-trainable params: 928
# __________________________________________________________________________________________________
# ResNet18v1
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 200/200 [==============================] - 15s 75ms/step - loss: 1.9703 - acc: 0.3283 - val_loss: 1.9313 - val_acc: 0.3496
#
# Epoch 00001: val_acc improved from -inf to 0.34960, saving model to /content/saved_models/cifar10_ResNet18v1_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 1.6954 - acc: 0.4198 - val_loss: 1.7605 - val_acc: 0.3946
#
# Epoch 00002: val_acc improved from 0.34960 to 0.39460, saving model to /content/saved_models/cifar10_ResNet18v1_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.6047 - acc: 0.4584 - val_loss: 1.8238 - val_acc: 0.4223
#
# Epoch 00003: val_acc improved from 0.39460 to 0.42230, saving model to /content/saved_models/cifar10_ResNet18v1_model.003.h5
# Epoch 4/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.5066 - acc: 0.4931 - val_loss: 1.4932 - val_acc: 0.4902
#
# Epoch 00004: val_acc improved from 0.42230 to 0.49020, saving model to /content/saved_models/cifar10_ResNet18v1_model.004.h5
# Epoch 5/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.4556 - acc: 0.5172 - val_loss: 1.8713 - val_acc: 0.4145
#
# Epoch 00005: val_acc did not improve from 0.49020
# Epoch 6/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.3826 - acc: 0.5508 - val_loss: 1.4250 - val_acc: 0.5236
#
# Epoch 00006: val_acc improved from 0.49020 to 0.52360, saving model to /content/saved_models/cifar10_ResNet18v1_model.006.h5
# Epoch 7/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.3289 - acc: 0.5613 - val_loss: 2.2425 - val_acc: 0.3757
#
# Epoch 00007: val_acc did not improve from 0.52360
# Epoch 8/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.3053 - acc: 0.5800 - val_loss: 1.5285 - val_acc: 0.5261
#
# Epoch 00008: val_acc improved from 0.52360 to 0.52610, saving model to /content/saved_models/cifar10_ResNet18v1_model.008.h5
# Epoch 9/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.2329 - acc: 0.5989 - val_loss: 1.2786 - val_acc: 0.5857
#
# Epoch 00009: val_acc improved from 0.52610 to 0.58570, saving model to /content/saved_models/cifar10_ResNet18v1_model.009.h5
# Epoch 10/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.1974 - acc: 0.6170 - val_loss: 1.6719 - val_acc: 0.5111
#
# Epoch 00010: val_acc did not improve from 0.58570
# Epoch 11/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.2003 - acc: 0.6130 - val_loss: 1.1821 - val_acc: 0.6168
#
# Epoch 00011: val_acc improved from 0.58570 to 0.61680, saving model to /content/saved_models/cifar10_ResNet18v1_model.011.h5
# Epoch 12/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.1428 - acc: 0.6338 - val_loss: 1.2449 - val_acc: 0.5995
#
# Epoch 00012: val_acc did not improve from 0.61680
# Epoch 13/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.1605 - acc: 0.6303 - val_loss: 1.1793 - val_acc: 0.6182
#
# Epoch 00013: val_acc improved from 0.61680 to 0.61820, saving model to /content/saved_models/cifar10_ResNet18v1_model.013.h5
# Epoch 14/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.1151 - acc: 0.6475 - val_loss: 1.2619 - val_acc: 0.5909
#
# Epoch 00014: val_acc did not improve from 0.61820
# Epoch 15/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.0946 - acc: 0.6561 - val_loss: 1.3589 - val_acc: 0.5847
#
# Epoch 00015: val_acc did not improve from 0.61820
# Epoch 16/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.0618 - acc: 0.6672 - val_loss: 1.2786 - val_acc: 0.6122
#
# Epoch 00016: val_acc did not improve from 0.61820
# Epoch 17/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 1.0563 - acc: 0.6722 - val_loss: 1.4396 - val_acc: 0.5635
#
# Epoch 00017: val_acc did not improve from 0.61820
# Epoch 18/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 1.0567 - acc: 0.6712 - val_loss: 1.3502 - val_acc: 0.5887
#
# Epoch 00018: val_acc did not improve from 0.61820
# Epoch 19/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 1.0145 - acc: 0.6863 - val_loss: 1.0214 - val_acc: 0.6791
#
# Epoch 00019: val_acc improved from 0.61820 to 0.67910, saving model to /content/saved_models/cifar10_ResNet18v1_model.019.h5
# Epoch 20/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 1.0009 - acc: 0.6875 - val_loss: 1.3653 - val_acc: 0.5847
#
# Epoch 00020: val_acc did not improve from 0.67910
# Epoch 21/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 1.0016 - acc: 0.6937 - val_loss: 1.4044 - val_acc: 0.5918
#
# Epoch 00021: val_acc did not improve from 0.67910
# Epoch 22/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.9550 - acc: 0.7094 - val_loss: 1.1885 - val_acc: 0.6365
#
# Epoch 00022: val_acc did not improve from 0.67910
# Epoch 23/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.9597 - acc: 0.7091 - val_loss: 1.3847 - val_acc: 0.5987
#
# Epoch 00023: val_acc did not improve from 0.67910
# Epoch 24/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.9345 - acc: 0.7195 - val_loss: 1.2104 - val_acc: 0.6435
#
# Epoch 00024: val_acc did not improve from 0.67910
# Epoch 25/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.9512 - acc: 0.7170 - val_loss: 1.0123 - val_acc: 0.6992
#
# Epoch 00025: val_acc improved from 0.67910 to 0.69920, saving model to /content/saved_models/cifar10_ResNet18v1_model.025.h5
# Epoch 26/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.8849 - acc: 0.7366 - val_loss: 1.0374 - val_acc: 0.6862
#
# Epoch 00026: val_acc did not improve from 0.69920
# Epoch 27/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.9129 - acc: 0.7314 - val_loss: 1.1938 - val_acc: 0.6575
#
# Epoch 00027: val_acc did not improve from 0.69920
# Epoch 28/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 36ms/step - loss: 0.9071 - acc: 0.7302 - val_loss: 1.3748 - val_acc: 0.6085
#
# Epoch 00028: val_acc did not improve from 0.69920
# Epoch 29/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.9031 - acc: 0.7325 - val_loss: 1.1339 - val_acc: 0.6685
#
# Epoch 00029: val_acc did not improve from 0.69920
# Epoch 30/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 36ms/step - loss: 0.8972 - acc: 0.7369 - val_loss: 1.0189 - val_acc: 0.6980
#
# Epoch 00030: val_acc did not improve from 0.69920
# Epoch 31/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 36ms/step - loss: 0.9052 - acc: 0.7322 - val_loss: 0.9463 - val_acc: 0.7148
#
# Epoch 00031: val_acc improved from 0.69920 to 0.71480, saving model to /content/saved_models/cifar10_ResNet18v1_model.031.h5
# Epoch 32/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 36ms/step - loss: 0.8706 - acc: 0.7448 - val_loss: 0.9559 - val_acc: 0.7177
#
# Epoch 00032: val_acc improved from 0.71480 to 0.71770, saving model to /content/saved_models/cifar10_ResNet18v1_model.032.h5
# Epoch 33/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 36ms/step - loss: 0.8533 - acc: 0.7517 - val_loss: 0.9086 - val_acc: 0.7378
#
# Epoch 00033: val_acc improved from 0.71770 to 0.73780, saving model to /content/saved_models/cifar10_ResNet18v1_model.033.h5
# Epoch 34/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.8708 - acc: 0.7377 - val_loss: 0.9947 - val_acc: 0.7041
#
# Epoch 00034: val_acc did not improve from 0.73780
# Epoch 35/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.8531 - acc: 0.7481 - val_loss: 0.9701 - val_acc: 0.7095
#
# Epoch 00035: val_acc did not improve from 0.73780
# Epoch 36/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.8304 - acc: 0.7541 - val_loss: 0.8249 - val_acc: 0.7659
#
# Epoch 00036: val_acc improved from 0.73780 to 0.76590, saving model to /content/saved_models/cifar10_ResNet18v1_model.036.h5
# Epoch 37/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 36ms/step - loss: 0.8463 - acc: 0.7498 - val_loss: 1.1227 - val_acc: 0.6791
#
# Epoch 00037: val_acc did not improve from 0.76590
# Epoch 38/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 36ms/step - loss: 0.8510 - acc: 0.7495 - val_loss: 0.9732 - val_acc: 0.7193
#
# Epoch 00038: val_acc did not improve from 0.76590
# Epoch 39/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.8286 - acc: 0.7602 - val_loss: 0.9262 - val_acc: 0.7294
#
# Epoch 00039: val_acc did not improve from 0.76590
# Epoch 40/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.7965 - acc: 0.7683 - val_loss: 0.9289 - val_acc: 0.7284
#
# Epoch 00040: val_acc did not improve from 0.76590
# Epoch 41/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.8273 - acc: 0.7611 - val_loss: 1.0558 - val_acc: 0.7084
#
# Epoch 00041: val_acc did not improve from 0.76590
# Epoch 42/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7965 - acc: 0.7670 - val_loss: 0.9246 - val_acc: 0.7380
#
# Epoch 00042: val_acc did not improve from 0.76590
# Epoch 43/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.8291 - acc: 0.7605 - val_loss: 1.0505 - val_acc: 0.7037
#
# Epoch 00043: val_acc did not improve from 0.76590
# Epoch 44/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7825 - acc: 0.7766 - val_loss: 1.4037 - val_acc: 0.6205
#
# Epoch 00044: val_acc did not improve from 0.76590
# Epoch 45/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.7991 - acc: 0.7706 - val_loss: 1.1108 - val_acc: 0.6953
#
# Epoch 00045: val_acc did not improve from 0.76590
# Epoch 46/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.7999 - acc: 0.7733 - val_loss: 0.9166 - val_acc: 0.7348
#
# Epoch 00046: val_acc did not improve from 0.76590
# Epoch 47/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 35ms/step - loss: 0.7965 - acc: 0.7723 - val_loss: 0.8569 - val_acc: 0.7546
#
# Epoch 00047: val_acc did not improve from 0.76590
# Epoch 48/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7975 - acc: 0.7666 - val_loss: 1.0631 - val_acc: 0.6943
#
# Epoch 00048: val_acc did not improve from 0.76590
# Epoch 49/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7655 - acc: 0.7870 - val_loss: 0.9489 - val_acc: 0.7207
#
# Epoch 00049: val_acc did not improve from 0.76590
# Epoch 50/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7675 - acc: 0.7847 - val_loss: 0.9857 - val_acc: 0.7283
#
# Epoch 00050: val_acc did not improve from 0.76590
# Epoch 51/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7759 - acc: 0.7805 - val_loss: 0.9149 - val_acc: 0.7414
#
# Epoch 00051: val_acc did not improve from 0.76590
# Epoch 52/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7263 - acc: 0.7931 - val_loss: 0.9502 - val_acc: 0.7341
#
# Epoch 00052: val_acc did not improve from 0.76590
# Epoch 53/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7709 - acc: 0.7830 - val_loss: 0.8885 - val_acc: 0.7477
#
# Epoch 00053: val_acc did not improve from 0.76590
# Epoch 54/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7786 - acc: 0.7783 - val_loss: 0.7891 - val_acc: 0.7710
#
# Epoch 00054: val_acc improved from 0.76590 to 0.77100, saving model to /content/saved_models/cifar10_ResNet18v1_model.054.h5
# Epoch 55/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7672 - acc: 0.7859 - val_loss: 1.0757 - val_acc: 0.7101
#
# Epoch 00055: val_acc did not improve from 0.77100
# Epoch 56/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7363 - acc: 0.7914 - val_loss: 0.9860 - val_acc: 0.7253
#
# Epoch 00056: val_acc did not improve from 0.77100
# Epoch 57/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7535 - acc: 0.7900 - val_loss: 0.8581 - val_acc: 0.7624
#
# Epoch 00057: val_acc did not improve from 0.77100
# Epoch 58/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7398 - acc: 0.7930 - val_loss: 0.8530 - val_acc: 0.7603
#
# Epoch 00058: val_acc did not improve from 0.77100
# Epoch 59/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7500 - acc: 0.7877 - val_loss: 0.9291 - val_acc: 0.7440
#
# Epoch 00059: val_acc did not improve from 0.77100
# Epoch 60/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7275 - acc: 0.7970 - val_loss: 0.9504 - val_acc: 0.7422
#
# Epoch 00060: val_acc did not improve from 0.77100
# Epoch 61/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 34ms/step - loss: 0.7485 - acc: 0.7941 - val_loss: 1.0314 - val_acc: 0.7156
#
# Epoch 00061: val_acc did not improve from 0.77100
# Epoch 62/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7543 - acc: 0.7886 - val_loss: 0.8705 - val_acc: 0.7538
#
# Epoch 00062: val_acc did not improve from 0.77100
# Epoch 63/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7221 - acc: 0.8067 - val_loss: 0.8884 - val_acc: 0.7466
#
# Epoch 00063: val_acc did not improve from 0.77100
# Epoch 64/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.7361 - acc: 0.7950 - val_loss: 0.8716 - val_acc: 0.7530
#
# Epoch 00064: val_acc did not improve from 0.77100
# Epoch 65/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7130 - acc: 0.8058 - val_loss: 0.8653 - val_acc: 0.7521
#
# Epoch 00065: val_acc did not improve from 0.77100
# Epoch 66/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.7180 - acc: 0.8031 - val_loss: 0.9227 - val_acc: 0.7518
#
# Epoch 00066: val_acc did not improve from 0.77100
# Epoch 67/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.7013 - acc: 0.8141 - val_loss: 0.9308 - val_acc: 0.7372
#
# Epoch 00067: val_acc did not improve from 0.77100
# Epoch 68/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7125 - acc: 0.8011 - val_loss: 1.1283 - val_acc: 0.7047
#
# Epoch 00068: val_acc did not improve from 0.77100
# Epoch 69/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.7365 - acc: 0.7942 - val_loss: 1.0432 - val_acc: 0.7189
#
# Epoch 00069: val_acc did not improve from 0.77100
# Epoch 70/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.7214 - acc: 0.8052 - val_loss: 0.8987 - val_acc: 0.7476
#
# Epoch 00070: val_acc did not improve from 0.77100
# Epoch 71/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7103 - acc: 0.8072 - val_loss: 0.8215 - val_acc: 0.7777
#
# Epoch 00071: val_acc improved from 0.77100 to 0.77770, saving model to /content/saved_models/cifar10_ResNet18v1_model.071.h5
# Epoch 72/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7089 - acc: 0.8050 - val_loss: 0.8635 - val_acc: 0.7662
#
# Epoch 00072: val_acc did not improve from 0.77770
# Epoch 73/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.6978 - acc: 0.8098 - val_loss: 0.8432 - val_acc: 0.7699
#
# Epoch 00073: val_acc did not improve from 0.77770
# Epoch 74/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.7074 - acc: 0.8066 - val_loss: 0.8513 - val_acc: 0.7776
#
# Epoch 00074: val_acc did not improve from 0.77770
# Epoch 75/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7132 - acc: 0.8089 - val_loss: 0.7984 - val_acc: 0.7795
#
# Epoch 00075: val_acc improved from 0.77770 to 0.77950, saving model to /content/saved_models/cifar10_ResNet18v1_model.075.h5
# Epoch 76/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.7008 - acc: 0.8098 - val_loss: 0.8253 - val_acc: 0.7737
#
# Epoch 00076: val_acc did not improve from 0.77950
# Epoch 77/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.7035 - acc: 0.8102 - val_loss: 0.7213 - val_acc: 0.7989
#
# Epoch 00077: val_acc improved from 0.77950 to 0.79890, saving model to /content/saved_models/cifar10_ResNet18v1_model.077.h5
# Epoch 78/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.6958 - acc: 0.8130 - val_loss: 0.8136 - val_acc: 0.7741
#
# Epoch 00078: val_acc did not improve from 0.79890
# Epoch 79/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.6894 - acc: 0.8177 - val_loss: 0.7550 - val_acc: 0.7927
#
# Epoch 00079: val_acc did not improve from 0.79890
# Epoch 80/200
# Learning rate:  0.001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.6739 - acc: 0.8219 - val_loss: 0.7837 - val_acc: 0.7855
#
# Epoch 00080: val_acc did not improve from 0.79890
# Epoch 81/200
# Learning rate:  0.001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.6770 - acc: 0.8163 - val_loss: 0.9010 - val_acc: 0.7550
#
# Epoch 00081: val_acc did not improve from 0.79890
# Epoch 82/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.6517 - acc: 0.8258 - val_loss: 0.6668 - val_acc: 0.8254
#
# Epoch 00082: val_acc improved from 0.79890 to 0.82540, saving model to /content/saved_models/cifar10_ResNet18v1_model.082.h5
# Epoch 83/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.6192 - acc: 0.8389 - val_loss: 0.6489 - val_acc: 0.8293
#
# Epoch 00083: val_acc improved from 0.82540 to 0.82930, saving model to /content/saved_models/cifar10_ResNet18v1_model.083.h5
# Epoch 84/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.6074 - acc: 0.8384 - val_loss: 0.6276 - val_acc: 0.8361
#
# Epoch 00084: val_acc improved from 0.82930 to 0.83610, saving model to /content/saved_models/cifar10_ResNet18v1_model.084.h5
# Epoch 85/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5925 - acc: 0.8506 - val_loss: 0.6283 - val_acc: 0.8371
#
# Epoch 00085: val_acc improved from 0.83610 to 0.83710, saving model to /content/saved_models/cifar10_ResNet18v1_model.085.h5
# Epoch 86/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.6044 - acc: 0.8436 - val_loss: 0.6179 - val_acc: 0.8388
#
# Epoch 00086: val_acc improved from 0.83710 to 0.83880, saving model to /content/saved_models/cifar10_ResNet18v1_model.086.h5
# Epoch 87/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5905 - acc: 0.8473 - val_loss: 0.6101 - val_acc: 0.8451
#
# Epoch 00087: val_acc improved from 0.83880 to 0.84510, saving model to /content/saved_models/cifar10_ResNet18v1_model.087.h5
# Epoch 88/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5665 - acc: 0.8561 - val_loss: 0.6341 - val_acc: 0.8347
#
# Epoch 00088: val_acc did not improve from 0.84510
# Epoch 89/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5679 - acc: 0.8538 - val_loss: 0.6052 - val_acc: 0.8468
#
# Epoch 00089: val_acc improved from 0.84510 to 0.84680, saving model to /content/saved_models/cifar10_ResNet18v1_model.089.h5
# Epoch 90/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5620 - acc: 0.8609 - val_loss: 0.6025 - val_acc: 0.8451
#
# Epoch 00090: val_acc did not improve from 0.84680
# Epoch 91/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5659 - acc: 0.8539 - val_loss: 0.6139 - val_acc: 0.8401
#
# Epoch 00091: val_acc did not improve from 0.84680
# Epoch 92/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5485 - acc: 0.8638 - val_loss: 0.6027 - val_acc: 0.8428
#
# Epoch 00092: val_acc did not improve from 0.84680
# Epoch 93/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5723 - acc: 0.8550 - val_loss: 0.6109 - val_acc: 0.8417
#
# Epoch 00093: val_acc did not improve from 0.84680
# Epoch 94/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5571 - acc: 0.8577 - val_loss: 0.5944 - val_acc: 0.8473
#
# Epoch 00094: val_acc improved from 0.84680 to 0.84730, saving model to /content/saved_models/cifar10_ResNet18v1_model.094.h5
# Epoch 95/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5557 - acc: 0.8642 - val_loss: 0.6141 - val_acc: 0.8419
#
# Epoch 00095: val_acc did not improve from 0.84730
# Epoch 96/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5583 - acc: 0.8586 - val_loss: 0.6081 - val_acc: 0.8422
#
# Epoch 00096: val_acc did not improve from 0.84730
# Epoch 97/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5547 - acc: 0.8600 - val_loss: 0.6008 - val_acc: 0.8453
#
# Epoch 00097: val_acc did not improve from 0.84730
# Epoch 98/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5505 - acc: 0.8561 - val_loss: 0.5984 - val_acc: 0.8457
#
# Epoch 00098: val_acc did not improve from 0.84730
# Epoch 99/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5578 - acc: 0.8617 - val_loss: 0.6193 - val_acc: 0.8401
#
# Epoch 00099: val_acc did not improve from 0.84730
# Epoch 100/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5487 - acc: 0.8638 - val_loss: 0.6067 - val_acc: 0.8446
#
# Epoch 00100: val_acc did not improve from 0.84730
# Epoch 101/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5316 - acc: 0.8658 - val_loss: 0.6085 - val_acc: 0.8452
#
# Epoch 00101: val_acc did not improve from 0.84730
# Epoch 102/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5429 - acc: 0.8686 - val_loss: 0.5947 - val_acc: 0.8472
#
# Epoch 00102: val_acc did not improve from 0.84730
# Epoch 103/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5436 - acc: 0.8650 - val_loss: 0.6113 - val_acc: 0.8411
#
# Epoch 00103: val_acc did not improve from 0.84730
# Epoch 104/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5394 - acc: 0.8636 - val_loss: 0.6173 - val_acc: 0.8396
#
# Epoch 00104: val_acc did not improve from 0.84730
# Epoch 105/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5374 - acc: 0.8636 - val_loss: 0.6067 - val_acc: 0.8445
#
# Epoch 00105: val_acc did not improve from 0.84730
# Epoch 106/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5459 - acc: 0.8591 - val_loss: 0.5853 - val_acc: 0.8507
#
# Epoch 00106: val_acc improved from 0.84730 to 0.85070, saving model to /content/saved_models/cifar10_ResNet18v1_model.106.h5
# Epoch 107/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5361 - acc: 0.8677 - val_loss: 0.5965 - val_acc: 0.8465
#
# Epoch 00107: val_acc did not improve from 0.85070
# Epoch 108/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5475 - acc: 0.8636 - val_loss: 0.6406 - val_acc: 0.8326
#
# Epoch 00108: val_acc did not improve from 0.85070
# Epoch 109/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5486 - acc: 0.8669 - val_loss: 0.5968 - val_acc: 0.8478
#
# Epoch 00109: val_acc did not improve from 0.85070
# Epoch 110/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5338 - acc: 0.8638 - val_loss: 0.6036 - val_acc: 0.8439
#
# Epoch 00110: val_acc did not improve from 0.85070
# Epoch 111/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5330 - acc: 0.8609 - val_loss: 0.6159 - val_acc: 0.8411
#
# Epoch 00111: val_acc did not improve from 0.85070
# Epoch 112/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5294 - acc: 0.8686 - val_loss: 0.5846 - val_acc: 0.8507
#
# Epoch 00112: val_acc did not improve from 0.85070
# Epoch 113/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5203 - acc: 0.8658 - val_loss: 0.5937 - val_acc: 0.8472
#
# Epoch 00113: val_acc did not improve from 0.85070
# Epoch 114/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5405 - acc: 0.8645 - val_loss: 0.6051 - val_acc: 0.8416
#
# Epoch 00114: val_acc did not improve from 0.85070
# Epoch 115/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5099 - acc: 0.8762 - val_loss: 0.5966 - val_acc: 0.8468
#
# Epoch 00115: val_acc did not improve from 0.85070
# Epoch 116/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5238 - acc: 0.8684 - val_loss: 0.5839 - val_acc: 0.8511
#
# Epoch 00116: val_acc improved from 0.85070 to 0.85110, saving model to /content/saved_models/cifar10_ResNet18v1_model.116.h5
# Epoch 117/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5286 - acc: 0.8655 - val_loss: 0.5836 - val_acc: 0.8511
#
# Epoch 00117: val_acc did not improve from 0.85110
# Epoch 118/200
# Learning rate:  0.0001
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5424 - acc: 0.8619 - val_loss: 0.6050 - val_acc: 0.8453
#
# Epoch 00118: val_acc did not improve from 0.85110
# Epoch 119/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5329 - acc: 0.8655 - val_loss: 0.5851 - val_acc: 0.8522
#
# Epoch 00119: val_acc improved from 0.85110 to 0.85220, saving model to /content/saved_models/cifar10_ResNet18v1_model.119.h5
# Epoch 120/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5084 - acc: 0.8717 - val_loss: 0.5850 - val_acc: 0.8479
#
# Epoch 00120: val_acc did not improve from 0.85220
# Epoch 121/200
# Learning rate:  0.0001
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5191 - acc: 0.8712 - val_loss: 0.5793 - val_acc: 0.8504
#
# Epoch 00121: val_acc did not improve from 0.85220
# Epoch 122/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5023 - acc: 0.8770 - val_loss: 0.5778 - val_acc: 0.8529
#
# Epoch 00122: val_acc improved from 0.85220 to 0.85290, saving model to /content/saved_models/cifar10_ResNet18v1_model.122.h5
# Epoch 123/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5054 - acc: 0.8769 - val_loss: 0.5803 - val_acc: 0.8515
#
# Epoch 00123: val_acc did not improve from 0.85290
# Epoch 124/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5292 - acc: 0.8680 - val_loss: 0.5779 - val_acc: 0.8531
#
# Epoch 00124: val_acc improved from 0.85290 to 0.85310, saving model to /content/saved_models/cifar10_ResNet18v1_model.124.h5
# Epoch 125/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5067 - acc: 0.8712 - val_loss: 0.5768 - val_acc: 0.8524
#
# Epoch 00125: val_acc did not improve from 0.85310
# Epoch 126/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5124 - acc: 0.8666 - val_loss: 0.5754 - val_acc: 0.8528
#
# Epoch 00126: val_acc did not improve from 0.85310
# Epoch 127/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4997 - acc: 0.8745 - val_loss: 0.5779 - val_acc: 0.8509
#
# Epoch 00127: val_acc did not improve from 0.85310
# Epoch 128/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5090 - acc: 0.8722 - val_loss: 0.5770 - val_acc: 0.8516
#
# Epoch 00128: val_acc did not improve from 0.85310
# Epoch 129/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5073 - acc: 0.8728 - val_loss: 0.5787 - val_acc: 0.8511
#
# Epoch 00129: val_acc did not improve from 0.85310
# Epoch 130/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5017 - acc: 0.8780 - val_loss: 0.5769 - val_acc: 0.8521
#
# Epoch 00130: val_acc did not improve from 0.85310
# Epoch 131/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5029 - acc: 0.8762 - val_loss: 0.5747 - val_acc: 0.8531
#
# Epoch 00131: val_acc did not improve from 0.85310
# Epoch 132/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5068 - acc: 0.8767 - val_loss: 0.5754 - val_acc: 0.8527
#
# Epoch 00132: val_acc did not improve from 0.85310
# Epoch 133/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5119 - acc: 0.8745 - val_loss: 0.5775 - val_acc: 0.8517
#
# Epoch 00133: val_acc did not improve from 0.85310
# Epoch 134/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5035 - acc: 0.8789 - val_loss: 0.5762 - val_acc: 0.8518
#
# Epoch 00134: val_acc did not improve from 0.85310
# Epoch 135/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4917 - acc: 0.8778 - val_loss: 0.5763 - val_acc: 0.8516
#
# Epoch 00135: val_acc did not improve from 0.85310
# Epoch 136/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5097 - acc: 0.8684 - val_loss: 0.5747 - val_acc: 0.8526
#
# Epoch 00136: val_acc did not improve from 0.85310
# Epoch 137/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5063 - acc: 0.8788 - val_loss: 0.5739 - val_acc: 0.8524
#
# Epoch 00137: val_acc did not improve from 0.85310
# Epoch 138/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4966 - acc: 0.8783 - val_loss: 0.5739 - val_acc: 0.8533
#
# Epoch 00138: val_acc improved from 0.85310 to 0.85330, saving model to /content/saved_models/cifar10_ResNet18v1_model.138.h5
# Epoch 139/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5047 - acc: 0.8759 - val_loss: 0.5777 - val_acc: 0.8513
#
# Epoch 00139: val_acc did not improve from 0.85330
# Epoch 140/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5126 - acc: 0.8727 - val_loss: 0.5757 - val_acc: 0.8518
#
# Epoch 00140: val_acc did not improve from 0.85330
# Epoch 141/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5155 - acc: 0.8706 - val_loss: 0.5760 - val_acc: 0.8519
#
# Epoch 00141: val_acc did not improve from 0.85330
# Epoch 142/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5007 - acc: 0.8738 - val_loss: 0.5742 - val_acc: 0.8520
#
# Epoch 00142: val_acc did not improve from 0.85330
# Epoch 143/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5073 - acc: 0.8744 - val_loss: 0.5740 - val_acc: 0.8530
#
# Epoch 00143: val_acc did not improve from 0.85330
# Epoch 144/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5034 - acc: 0.8730 - val_loss: 0.5706 - val_acc: 0.8535
#
# Epoch 00144: val_acc improved from 0.85330 to 0.85350, saving model to /content/saved_models/cifar10_ResNet18v1_model.144.h5
# Epoch 145/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5050 - acc: 0.8766 - val_loss: 0.5749 - val_acc: 0.8525
#
# Epoch 00145: val_acc did not improve from 0.85350
# Epoch 146/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4826 - acc: 0.8806 - val_loss: 0.5741 - val_acc: 0.8538
#
# Epoch 00146: val_acc improved from 0.85350 to 0.85380, saving model to /content/saved_models/cifar10_ResNet18v1_model.146.h5
# Epoch 147/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5040 - acc: 0.8717 - val_loss: 0.5766 - val_acc: 0.8521
#
# Epoch 00147: val_acc did not improve from 0.85380
# Epoch 148/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5002 - acc: 0.8766 - val_loss: 0.5745 - val_acc: 0.8527
#
# Epoch 00148: val_acc did not improve from 0.85380
# Epoch 149/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5105 - acc: 0.8703 - val_loss: 0.5759 - val_acc: 0.8529
#
# Epoch 00149: val_acc did not improve from 0.85380
# Epoch 150/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5011 - acc: 0.8745 - val_loss: 0.5742 - val_acc: 0.8526
#
# Epoch 00150: val_acc did not improve from 0.85380
# Epoch 151/200
# Learning rate:  1e-05
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4880 - acc: 0.8781 - val_loss: 0.5776 - val_acc: 0.8520
#
# Epoch 00151: val_acc did not improve from 0.85380
# Epoch 152/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4921 - acc: 0.8786 - val_loss: 0.5737 - val_acc: 0.8535
#
# Epoch 00152: val_acc did not improve from 0.85380
# Epoch 153/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4918 - acc: 0.8752 - val_loss: 0.5762 - val_acc: 0.8530
#
# Epoch 00153: val_acc did not improve from 0.85380
# Epoch 154/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5046 - acc: 0.8761 - val_loss: 0.5743 - val_acc: 0.8531
#
# Epoch 00154: val_acc did not improve from 0.85380
# Epoch 155/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5187 - acc: 0.8720 - val_loss: 0.5773 - val_acc: 0.8513
#
# Epoch 00155: val_acc did not improve from 0.85380
# Epoch 156/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4937 - acc: 0.8795 - val_loss: 0.5769 - val_acc: 0.8525
#
# Epoch 00156: val_acc did not improve from 0.85380
# Epoch 157/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4990 - acc: 0.8805 - val_loss: 0.5747 - val_acc: 0.8531
#
# Epoch 00157: val_acc did not improve from 0.85380
# Epoch 158/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5109 - acc: 0.8669 - val_loss: 0.5714 - val_acc: 0.8548
#
# Epoch 00158: val_acc improved from 0.85380 to 0.85480, saving model to /content/saved_models/cifar10_ResNet18v1_model.158.h5
# Epoch 159/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5137 - acc: 0.8678 - val_loss: 0.5715 - val_acc: 0.8548
#
# Epoch 00159: val_acc did not improve from 0.85480
# Epoch 160/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4967 - acc: 0.8812 - val_loss: 0.5711 - val_acc: 0.8541
#
# Epoch 00160: val_acc did not improve from 0.85480
# Epoch 161/200
# Learning rate:  1e-05
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5032 - acc: 0.8756 - val_loss: 0.5703 - val_acc: 0.8555
#
# Epoch 00161: val_acc improved from 0.85480 to 0.85550, saving model to /content/saved_models/cifar10_ResNet18v1_model.161.h5
# Epoch 162/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5045 - acc: 0.8764 - val_loss: 0.5760 - val_acc: 0.8542
#
# Epoch 00162: val_acc did not improve from 0.85550
# Epoch 163/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4952 - acc: 0.8733 - val_loss: 0.5731 - val_acc: 0.8550
#
# Epoch 00163: val_acc did not improve from 0.85550
# Epoch 164/200
# Learning rate:  1e-06
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4780 - acc: 0.8833 - val_loss: 0.5710 - val_acc: 0.8549
#
# Epoch 00164: val_acc did not improve from 0.85550
# Epoch 165/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5010 - acc: 0.8756 - val_loss: 0.5720 - val_acc: 0.8551
#
# Epoch 00165: val_acc did not improve from 0.85550
# Epoch 166/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4988 - acc: 0.8786 - val_loss: 0.5713 - val_acc: 0.8540
#
# Epoch 00166: val_acc did not improve from 0.85550
# Epoch 167/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4976 - acc: 0.8750 - val_loss: 0.5716 - val_acc: 0.8543
#
# Epoch 00167: val_acc did not improve from 0.85550
# Epoch 168/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4812 - acc: 0.8791 - val_loss: 0.5730 - val_acc: 0.8544
#
# Epoch 00168: val_acc did not improve from 0.85550
# Epoch 169/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4965 - acc: 0.8775 - val_loss: 0.5742 - val_acc: 0.8547
#
# Epoch 00169: val_acc did not improve from 0.85550
# Epoch 170/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5015 - acc: 0.8789 - val_loss: 0.5745 - val_acc: 0.8543
#
# Epoch 00170: val_acc did not improve from 0.85550
# Epoch 171/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4902 - acc: 0.8794 - val_loss: 0.5757 - val_acc: 0.8541
#
# Epoch 00171: val_acc did not improve from 0.85550
# Epoch 172/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5114 - acc: 0.8719 - val_loss: 0.5744 - val_acc: 0.8549
#
# Epoch 00172: val_acc did not improve from 0.85550
# Epoch 173/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5042 - acc: 0.8775 - val_loss: 0.5717 - val_acc: 0.8556
#
# Epoch 00173: val_acc improved from 0.85550 to 0.85560, saving model to /content/saved_models/cifar10_ResNet18v1_model.173.h5
# Epoch 174/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4977 - acc: 0.8772 - val_loss: 0.5712 - val_acc: 0.8550
#
# Epoch 00174: val_acc did not improve from 0.85560
# Epoch 175/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5072 - acc: 0.8727 - val_loss: 0.5722 - val_acc: 0.8559
#
# Epoch 00175: val_acc improved from 0.85560 to 0.85590, saving model to /content/saved_models/cifar10_ResNet18v1_model.175.h5
# Epoch 176/200
# Learning rate:  1e-06
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4875 - acc: 0.8736 - val_loss: 0.5722 - val_acc: 0.8547
#
# Epoch 00176: val_acc did not improve from 0.85590
# Epoch 177/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4873 - acc: 0.8766 - val_loss: 0.5722 - val_acc: 0.8546
#
# Epoch 00177: val_acc did not improve from 0.85590
# Epoch 178/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5027 - acc: 0.8725 - val_loss: 0.5723 - val_acc: 0.8547
#
# Epoch 00178: val_acc did not improve from 0.85590
# Epoch 179/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4974 - acc: 0.8836 - val_loss: 0.5704 - val_acc: 0.8544
#
# Epoch 00179: val_acc did not improve from 0.85590
# Epoch 180/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5105 - acc: 0.8717 - val_loss: 0.5755 - val_acc: 0.8536
#
# Epoch 00180: val_acc did not improve from 0.85590
# Epoch 181/200
# Learning rate:  1e-06
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5113 - acc: 0.8719 - val_loss: 0.5719 - val_acc: 0.8551
#
# Epoch 00181: val_acc did not improve from 0.85590
# Epoch 182/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4983 - acc: 0.8784 - val_loss: 0.5707 - val_acc: 0.8549
#
# Epoch 00182: val_acc did not improve from 0.85590
# Epoch 183/200
# Learning rate:  5e-07
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4985 - acc: 0.8761 - val_loss: 0.5736 - val_acc: 0.8552
#
# Epoch 00183: val_acc did not improve from 0.85590
# Epoch 184/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5068 - acc: 0.8691 - val_loss: 0.5737 - val_acc: 0.8543
#
# Epoch 00184: val_acc did not improve from 0.85590
# Epoch 185/200
# Learning rate:  5e-07
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4799 - acc: 0.8814 - val_loss: 0.5719 - val_acc: 0.8544
#
# Epoch 00185: val_acc did not improve from 0.85590
# Epoch 186/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4975 - acc: 0.8758 - val_loss: 0.5731 - val_acc: 0.8536
#
# Epoch 00186: val_acc did not improve from 0.85590
# Epoch 187/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4798 - acc: 0.8830 - val_loss: 0.5735 - val_acc: 0.8543
#
# Epoch 00187: val_acc did not improve from 0.85590
# Epoch 188/200
# Learning rate:  5e-07
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4960 - acc: 0.8777 - val_loss: 0.5724 - val_acc: 0.8546
#
# Epoch 00188: val_acc did not improve from 0.85590
# Epoch 189/200
# Learning rate:  5e-07
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4971 - acc: 0.8767 - val_loss: 0.5723 - val_acc: 0.8548
#
# Epoch 00189: val_acc did not improve from 0.85590
# Epoch 190/200
# Learning rate:  5e-07
# 200/200 [==============================] - 7s 33ms/step - loss: 0.4885 - acc: 0.8783 - val_loss: 0.5717 - val_acc: 0.8549
#
# Epoch 00190: val_acc did not improve from 0.85590
# Epoch 191/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5020 - acc: 0.8752 - val_loss: 0.5744 - val_acc: 0.8548
#
# Epoch 00191: val_acc did not improve from 0.85590
# Epoch 192/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5003 - acc: 0.8780 - val_loss: 0.5735 - val_acc: 0.8548
#
# Epoch 00192: val_acc did not improve from 0.85590
# Epoch 193/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4945 - acc: 0.8786 - val_loss: 0.5750 - val_acc: 0.8540
#
# Epoch 00193: val_acc did not improve from 0.85590
# Epoch 194/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5013 - acc: 0.8769 - val_loss: 0.5738 - val_acc: 0.8533
#
# Epoch 00194: val_acc did not improve from 0.85590
# Epoch 195/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4992 - acc: 0.8745 - val_loss: 0.5721 - val_acc: 0.8543
#
# Epoch 00195: val_acc did not improve from 0.85590
# Epoch 196/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.5143 - acc: 0.8709 - val_loss: 0.5747 - val_acc: 0.8537
#
# Epoch 00196: val_acc did not improve from 0.85590
# Epoch 197/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4951 - acc: 0.8769 - val_loss: 0.5719 - val_acc: 0.8545
#
# Epoch 00197: val_acc did not improve from 0.85590
# Epoch 198/200
# Learning rate:  5e-07
# 200/200 [==============================] - 7s 33ms/step - loss: 0.5039 - acc: 0.8712 - val_loss: 0.5736 - val_acc: 0.8543
#
# Epoch 00198: val_acc did not improve from 0.85590
# Epoch 199/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4872 - acc: 0.8784 - val_loss: 0.5743 - val_acc: 0.8545
#
# Epoch 00199: val_acc did not improve from 0.85590
# Epoch 200/200
# Learning rate:  5e-07
# 200/200 [==============================] - 6s 32ms/step - loss: 0.4888 - acc: 0.8789 - val_loss: 0.5727 - val_acc: 0.8551
#
# Epoch 00200: val_acc did not improve from 0.85590
# 10000/10000 [==============================] - 1s 131us/step
# Test loss: 0.5726597400188446
# Test accuracy: 0.8551

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

# %%
predicted = model.predict(x_test)

# %%
class_idx = np.argmax(predicted[6])

# %%
class_idx
# Out:
# 1

# %%
class_idx_orig = np.argmax(y_test[5])

# %%
class_idx_orig
# Out:
# 0

# %%
misclassified = []

# %%
for image in range(len(x_test)):
  if (np.argmax(predicted[image]) != np.argmax(y_test[image])):
    misclassified.append(x_test[image])

# %%
len(x_test)
# Out:
# 10000

# %%
len(misclassified)
# Out:
# 0

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import keras.backend as K
import numpy as np
import cv2
import sys

# %%
type(misclassified[0])
# Out:
# numpy.ndarray

# %%
type(heatmap)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Creating Gradcam Results on Misclassified Images

# %%
for i in range(51):
  x = np.expand_dims(misclassified[i], axis=0)
  class_idx = np.argmax(model.predict(x))
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("conv2d_36")
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
#   x = np.expand_dims(misclassified[i], axis=0)
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for j in range(64):
    conv_layer_output_value[:, :, j] *= pooled_grads_value[j]
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  img = misclassified[i]

  heatmap = cv2.resize(heatmap, (misclassified[i].shape[1], misclassified[i].shape[0]))
  heatmap = np.uint8(255 * heatmap)
  img = np.uint8(255 * img)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
  filename = "gallery"+str(i)+".jpg"
  plt.imsave(filename, superimposed_img)

# %%
cd app/
# Out:
# /content/drive/My Drive/app

# %%
# #model = VGG16(weights="imagenet")
# img_path = sys.argv[1]
# img = image.load_img(img_path, target_size=(224, 224))
# x = image.img_to_array(img)
# x = np.expand_dims(x, axis=0)
# x = preprocess_input(x)

# %%
last_conv_layer.output_shape
# Out:
# (None, 8, 8, 64)

# %%
x_test[0].shape
# Out:
# (32, 32, 3)

# %%
x = np.expand_dims(x_test[0], axis=0)

# %%
x.shape
# Out:
# (1, 32, 32, 3)

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
grads = K.gradients(class_output, last_conv_layer.output)[0]
pooled_grads = K.mean(grads, axis=(0, 1, 2))
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
pooled_grads_value, conv_layer_output_value = iterate([x])
for i in range(64):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

# %%
from google.colab.patches import cv2_imshow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# x_train = x_train / 255.0
# x_test = x_test / 255.0

# %%
plt.imshow(x_test[6])

# %%
plt.imsave("gallery.jpg", superimposed_img)

# %%
plt.imshow(superimposed_img)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
